# %%
import pandas as pd
import re,string
import nltk
from patsy import dmatrices
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib.pyplot as plt
import warnings
# %pylab inline
import numpy as np
from sklearn.manifold import MDS
from sklearn.metrics import euclidean_distances
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
amazon_data = pd.read_csv('amazon.csv')

# %%
amazon_data.head()
# Out:
#                                                Title Date Written  Rating  \
# 0                                  "Account Manager"  Sep 9, 2018     3.0
# 1  "All the "bad" things you heard about Amazon i...  Sep 9, 2018     1.0
# 2      "Amazon is giving hard time to the employees"  Sep 9, 2018     1.0
# 3                       "Amazon Warehouse Operative"  Sep 9, 2018     1.0
# 4  "Amazon was the easiest job and I was surround...  Sep 9, 2018     5.0
#
#      Current/Former           Job Title           Location    Recommendation?  \
# 0   Former Employee  Anonymous Employee                NaN         Recommends
# 1   Former Employee  Software Developer        Seattle, WA  Doesn't Recommend
# 2  Current Employee    Fruad Prevention  Hyderabad (India)  Doesn't Recommend
# 3  Current Employee  Anonymous Employee                NaN  Doesn't Recommend
# 4   Former Employee           Associate          Essex, MD         Recommends
#
#             Outlook                                        Main Text  \
# 0               NaN             - Fun environment and excellent team
# 1  Negative Outlook  I worked at Amazon full-time (More than a year)
# 2  Negative Outlook                        Becoming worst day by day
# 3  Negative Outlook          I have been working at Amazon full-time
# 4  Positive Outlook  I worked at Amazon full-time (Less than a year)
#
#                                                 Pros  \
# 0                               - Proactive scenario
# 1                    You get to work a LOT of hours.
# 2  All I can say is Amazon has been changed drast...
# 3                              Weekly pay was a plus
# 4  Fun, easy, positive energy, surrounded by cool...
#
#                                                 Cons Advice to management
# 0  Almost none opportunities to grow or to move t...                  NaN
# 1  Work life balance is extremely bad. Work here ...             Hopeless
# 2                       Working at Amazon is the con                  NaN
# 3  Treated as a number, long hours and no flexibi...    Treat staff equal
# 4             Long hours but youâll get used to it                  NaN

# %% [markdown]
# # Pros
#
#
# ### Step 1: pros/cons data pre-processing

# %%
#clean punctuation and white spaces
amazon_data["pros_clean"] = amazon_data.Pros.apply(lambda x:re.sub(r'[^\w\s]', ' ', str(x).lower()))
amazon_data["pros_clean"] = amazon_data.pros_clean.apply(lambda x:re.sub(r'(\\n+)', ' ', x))
amazon_data["pros_clean"] = amazon_data.pros_clean.apply(lambda x:re.sub(r'^b[\'\"\'"\"''\s]', '', x.lower()))
amazon_data["pros_clean"] = amazon_data.pros_clean.apply(lambda x:re.sub(r'\s+', ' ', x))

amazon_data["cons_clean"] = amazon_data.Cons.apply(lambda x:re.sub(r'[^\w\s]', ' ', str(x).lower()))
amazon_data["cons_clean"] = amazon_data.cons_clean.apply(lambda x:re.sub(r'(\\n+)', ' ', x))
amazon_data["cons_clean"] = amazon_data.cons_clean.apply(lambda x:re.sub(r'^b[\'\"\'"\"''\s]', '', x.lower()))
amazon_data["cons_clean"] = amazon_data.cons_clean.apply(lambda x:re.sub(r'\s+', ' ', x))

#tokenizing and removing stop words
stop = set(stopwords.words('english'))
punc = string.punctuation
amazon_data['pros_clean'] = amazon_data.pros_clean.apply(lambda x: [word for word in word_tokenize(x) if word not in stop])
amazon_data['pros_clean'] = amazon_data['pros_clean'].apply(lambda x: [word for word in x if word not in punc])
amazon_data['cons_clean'] = amazon_data.cons_clean.apply(lambda x: [word for word in word_tokenize(x) if word not in stop])
amazon_data['cons_clean'] = amazon_data['cons_clean'].apply(lambda x: [word for word in x if word not in punc])

amazon_data.head()
# Out:
#                                                Title Date Written  Rating  \
# 0                                  "Account Manager"  Sep 9, 2018     3.0
# 1  "All the "bad" things you heard about Amazon i...  Sep 9, 2018     1.0
# 2      "Amazon is giving hard time to the employees"  Sep 9, 2018     1.0
# 3                       "Amazon Warehouse Operative"  Sep 9, 2018     1.0
# 4  "Amazon was the easiest job and I was surround...  Sep 9, 2018     5.0
#
#      Current/Former           Job Title           Location    Recommendation?  \
# 0   Former Employee  Anonymous Employee                NaN         Recommends
# 1   Former Employee  Software Developer        Seattle, WA  Doesn't Recommend
# 2  Current Employee    Fruad Prevention  Hyderabad (India)  Doesn't Recommend
# 3  Current Employee  Anonymous Employee                NaN  Doesn't Recommend
# 4   Former Employee           Associate          Essex, MD         Recommends
#
#             Outlook                                        Main Text  \
# 0               NaN             - Fun environment and excellent team
# 1  Negative Outlook  I worked at Amazon full-time (More than a year)
# 2  Negative Outlook                        Becoming worst day by day
# 3  Negative Outlook          I have been working at Amazon full-time
# 4  Positive Outlook  I worked at Amazon full-time (Less than a year)
#
#                                                 Pros  \
# 0                                 proactive scenario
# 1                            you get work lot hours
# 2  all can say amazon has been changed drasticall...
# 3                                weekly pay was plus
# 4   fun easy positive energy surrounded cool people
#
#                                                 Cons Advice to management  \
# 0  Almost none opportunities to grow or to move t...                  NaN
# 1  Work life balance is extremely bad. Work here ...             Hopeless
# 2                       Working at Amazon is the con                  NaN
# 3  Treated as a number, long hours and no flexibi...    Treat staff equal
# 4               Long hours but you’ll get used to it                  NaN
#
#                                           pros_clean  \
# 0                              [proactive, scenario]
# 1                            [get, work, lot, hours]
# 2  [say, amazon, changed, drastically, trying, im...
# 3                                [weekly, pay, plus]
# 4  [fun, easy, positive, energy, surrounded, cool...
#
#                                           cons_clean
# 0  [almost, none, opportunities, grow, move, anot...
# 1  [work, life, balance, extremely, bad, work, pl...
# 2                             [working, amazon, con]
# 3  [treated, number, long, hours, flexibility, work]
# 4                           [long, hours, get, used]

# %% [markdown]
# ### Step 2: get pros/cons attributes

# %%
#manually took some attributes from the top frequent pros words
pros_attribute = ['great','good','happy','nice','decent','excellent','best','ethical','strong','flexible','new',
                  'easy','friendly','positive','different','professional','high','solid','corporate',
                  'smart','stable','large']

# %%
#manually took some attributes from the top frequent cons words
cons_attribute = ['low','little','hard','difficult','long','poor','limited','bad','slow','terrible','conservative'
                 ,'horrible','different','less','senior','political','bureaucratic']

# %% [markdown]
# ### Step 3: lemmentize -> get replacement

# %%
replacement = {'work_life_balance':['time','life','balance','sabbatical','sabbaticals','focus','hour','day','health','flexible','week'
                                    ,'vacation','schedule','overtime'],
                'culture_value':['people','culture','team','care','value','product','coworkers','atmosphere','competitive'
                                ,'family','collaboration','respect','community','colleague','supportive','vision','diversity'],
                'career_oppotunity':['opportunity','learn','industry','career','license','training','train','growth','grow'
                                    ,'level','position','development','advancement','advance','study','build','skill','resource'
                                    ,'education','potential'],
                'company_benefit':['company','benefit','pay','financial','financially','provide','salary','bonus','offer'
                                  ,'401k','package','stock','compensation','invest','investment','money','performance','reward'
                                  ,'retirement','promote','insurance'],
                'senior_management':['place','environment','management','help','manager','experience','match'
                                                ,'plan','office','support','location','leadership','treat','helpful','senior'
                                                ,'manage','leader','communication']}

# %%
def getKeysByValue(dictOfElements, valueToFind):
    for k,v  in dictOfElements.items():
        if valueToFind in v:
            return(k)
    return  valueToFind

def replace_attributes(s):
    return([getKeysByValue(replacement,y) for y in s])

# %%
amazon_data['pros_replace'] = amazon_data['pros_clean'].map(replace_attributes)
amazon_data['cons_replace'] = amazon_data['cons_clean'].map(replace_attributes)

# %% [markdown]
# ### Step 4: Lift Score

# %%
def ratio(x,y):
    if x==0:
        return float(y)
    if y==0:
        return float(x)
    return(float(x)*float(y))

def get_lift(a,b,tokenized_data):
    '''Function to calculate lift scores given any two words from a list of tokenized words'''
    if (a==b):
        return 1
    p_a = len([i for i in tokenized_data if a in i])
    p_b = len([i for i in tokenized_data if (b in i)])
    p_a_b = len([i for i in tokenized_data if a in i if b in i])
    n = len(tokenized_data)
    return float(float(n)*float(p_a_b)/ratio(p_a,p_b))

# %%
pros_list = replacement.keys()
lift_score = [get_lift(x,y,amazon_data.pros_replace) for x in pros_attribute for y in pros_list]
formatted_lift_score = [ round(elem,2) for elem in lift_score ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(pros_attribute),len(pros_list))),index =pros_attribute , columns = pros_list )
# Out:
#               culture_value  company_benefit  senior_management  \
# great                  1.34             1.28               1.39
# good                   1.03             1.46               1.19
# happy                  1.49             1.01               1.46
# nice                   1.54             1.16               1.51
# decent                 0.74             2.51               0.66
# excellent              1.35             1.21               1.54
# best                   1.26             1.00               1.62
# ethical                1.17             2.04               0.60
# strong                 2.14             1.21               1.55
# flexible               0.00             0.00               0.00
# new                    1.34             0.86               1.36
# easy                   0.85             1.13               0.82
# friendly               1.55             0.83               2.07
# positive               1.88             1.00               1.90
# different              1.47             1.10               1.33
# professional           1.44             0.89               1.95
# high                   1.26             1.41               1.12
# solid                  1.15             1.92               1.34
# corporate              1.85             1.30               1.41
# smart                  2.96             0.82               1.04
# stable                 0.56             1.75               0.58
# large                  1.33             1.44               1.33
#
#               work_life_balance  career_oppotunity
# great                      1.03               1.22
# good                       1.04               0.92
# happy                      1.67               1.17
# nice                       1.10               0.73
# decent                     1.64               0.73
# excellent                  1.06               1.31
# best                       0.86               1.43
# ethical                    1.75               1.53
# strong                     0.96               1.48
# flexible                   0.00               0.00
# new                        1.21               2.35
# easy                       1.58               0.84
# friendly                   1.01               0.74
# positive                   1.23               1.15
# different                  1.24               2.01
# professional               0.92               2.42
# high                       0.92               1.70
# solid                      1.50               1.64
# corporate                  0.72               1.53
# smart                      0.58               1.31
# stable                     1.78               1.31
# large                      0.75               1.89

# %%
cons_list = replacement.keys()
lift_score = [get_lift(x,y,amazon_data.cons_replace) for x in cons_attribute for y in cons_list]
formatted_lift_score = [ round(elem,2) for elem in lift_score ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(cons_attribute),len(cons_list))),index =cons_attribute , columns = cons_list )
# Out:
#               culture_value  company_benefit  senior_management  \
# low                    0.89             3.97               1.03
# little                 1.44             1.57               1.43
# hard                   1.38             1.23               1.12
# difficult              1.23             0.94               1.35
# long                   0.82             0.86               0.85
# poor                   1.29             1.42               2.28
# limited                0.98             1.28               0.94
# bad                    1.67             1.34               1.69
# slow                   0.90             1.13               0.70
# terrible               2.10             1.62               2.41
# conservative           5.76             0.00               4.11
# horrible               1.95             1.30               2.33
# different              2.17             1.42               1.48
# less                   1.26             2.27               0.89
# senior                 0.00             0.00               0.00
# political              2.06             1.16               2.00
# bureaucratic           1.50             1.24               1.16
#
#               work_life_balance  career_oppotunity
# low                        0.86               1.78
# little                     1.34               1.88
# hard                       1.18               1.27
# difficult                  1.35               1.70
# long                       1.38               0.83
# poor                       1.49               1.70
# limited                    1.27               3.04
# bad                        1.17               1.06
# slow                       0.75               3.44
# terrible                   1.45               1.54
# conservative               0.00               0.00
# horrible                   1.59               1.46
# different                  1.23               1.91
# less                       1.23               1.58
# senior                     0.00               0.00
# political                  1.00               1.65
# bureaucratic               0.85               1.03

# %% [markdown]
# ### Lift for mission Statement

# %% [markdown]
#     for Pros

# %%
amazon_values = ['simplicity', 'ownership','courage','frugality','trust','think big', 'customer obsession']

# %%
mission_lift = [get_lift(x,y,amazon_data.pros_replace) for x in amazon_values for y in pros_list]
formatted_lift_score = [ round(elem,2) for elem in mission_lift ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(amazon_values),len(pros_list))),index =amazon_values , columns = pros_list )
# Out:
#                     culture_value  company_benefit  senior_management  \
# simplicity                   0.00             3.06               0.00
# ownership                    1.31             0.49               1.04
# courage                      0.00             0.00               0.00
# frugality                    1.91             1.67               0.99
# trust                        1.61             1.10               1.85
# think big                    0.00             0.00               0.00
# customer obsession           0.00             0.00               0.00
#
#                     work_life_balance  career_oppotunity
# simplicity                       0.00               4.60
# ownership                        0.66               1.54
# courage                          0.00               0.00
# frugality                        0.48               2.09
# trust                            0.67               1.30
# think big                        0.00               0.00
# customer obsession               0.00               0.00

# %% [markdown]
#     for Cons

# %%
mission_lift = [get_lift(x,y,amazon_data.cons_replace) for x in amazon_values for y in cons_list]
formatted_lift_score = [ round(elem,2) for elem in mission_lift ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(amazon_values),len(cons_list))),index =amazon_values , columns = cons_list )
# Out:
#                     culture_value  company_benefit  senior_management  \
# simplicity                   0.00             0.00               0.00
# ownership                    2.09             0.93               1.72
# courage                      2.88             0.00               2.06
# frugality                    1.74             2.04               1.22
# trust                        2.88             1.20               2.27
# think big                    0.00             0.00               0.00
# customer obsession           0.00             0.00               0.00
#
#                     work_life_balance  career_oppotunity
# simplicity                       0.00               0.00
# ownership                        1.35               1.44
# courage                          0.00               0.00
# frugality                        0.94               0.93
# trust                            1.03               1.87
# think big                        0.00               0.00
# customer obsession               0.00               0.00
