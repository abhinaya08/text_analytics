# %%
import pandas as pd
import re,string
import nltk
from patsy import dmatrices
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib.pyplot as plt
import warnings
# %pylab inline
import numpy as np
from sklearn.manifold import MDS
from sklearn.metrics import euclidean_distances
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dell_data = pd.read_csv('Dell_csv.csv')

# %%
dell_data.head()
# Out:
#                                                Title  Date Written  Rating  \
# 0                                "Financial Analyst"  Sep 24, 2018     5.0
# 1                            "Sr Principal Engineer"  Sep 27, 2018     4.0
# 2                               "Good Place to work"  Sep 28, 2018     4.0
# 3  "I enjoy working here, but my compensation is ...  Sep 25, 2018     4.0
# 4                        "Technical Support Manager"  Sep 26, 2018     4.0
#
#      Current/Former              Job Title      Location Recommendation?  \
# 0  Current Employee     Anonymous Employee           NaN             NaN
# 1  Current Employee              Architect    Austin, TX      Recommends
# 2  Current Employee     Anonymous Employee           NaN             NaN
# 3  Current Employee  Senior Representative  Franklin, MA      Recommends
# 4   Former Employee     Anonymous Employee           NaN      Recommends
#
#             Outlook                                          Main Text  \
# 0               NaN              I have been working at Dell full-time
# 1  Positive Outlook  Oct 2, 2018 – Candidate and Employee Experienc...
# 2               NaN                                                NaN
# 3   Neutral Outlook  I have been working at Dell full-time (More th...
# 4  Positive Outlook                         I worked at Dell part-time
#
#                                                 Pros  \
# 0                 Company culture, work life balance
# 1                              Good work environment
# 2  Flexibility in work, Friendly environment,scop...
# 3  I like my job, I have a lot of responsibility,...
# 4                  Competitive salary, great culture
#
#                                                 Cons  \
# 0  High achieving individuals may feel underemployed
# 1                                 Slow career growth
# 2  Lack of communication gap between team members...
# 3  My pay does not reflect the level of difficult...
# 4  Career growth limited at the management level ...
#
#                                 Advice to management
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  I would like more opportunities for growth in ...
# 4  promote more african Americans to senior manag...

# %% [markdown]
# ### Step 1: pros/cons data pre-processing

# %%
#clean punctuation and white spaces
dell_data["pros_clean"] = dell_data.Pros.apply(lambda x:re.sub(r'[^\w\s]', ' ', x.lower()))
dell_data["pros_clean"] = dell_data.pros_clean.apply(lambda x:re.sub(r'(\\n+)', ' ', x))
dell_data["pros_clean"] = dell_data.pros_clean.apply(lambda x:re.sub(r'^b[\'\"\'"\"''\s]', '', x.lower()))
dell_data["pros_clean"] = dell_data.pros_clean.apply(lambda x:re.sub(r'\s+', ' ', x))

dell_data["cons_clean"] = dell_data.Cons.apply(lambda x:re.sub(r'[^\w\s]', ' ', x.lower()))
dell_data["cons_clean"] = dell_data.cons_clean.apply(lambda x:re.sub(r'(\\n+)', ' ', x))
dell_data["cons_clean"] = dell_data.cons_clean.apply(lambda x:re.sub(r'^b[\'\"\'"\"''\s]', '', x.lower()))
dell_data["cons_clean"] = dell_data.cons_clean.apply(lambda x:re.sub(r'\s+', ' ', x))

#tokenizing and removing stop words
stop = set(stopwords.words('english'))
punc = string.punctuation
dell_data['pros_clean'] = dell_data.pros_clean.apply(lambda x: [word for word in word_tokenize(x) if word not in stop])
dell_data['pros_clean'] = dell_data['pros_clean'].apply(lambda x: [word for word in x if word not in punc])
dell_data['cons_clean'] = dell_data.cons_clean.apply(lambda x: [word for word in word_tokenize(x) if word not in stop])
dell_data['cons_clean'] = dell_data['cons_clean'].apply(lambda x: [word for word in x if word not in punc])

dell_data.head()
# Out:
#                                                Title  Date Written  Rating  \
# 0                                "Financial Analyst"  Sep 24, 2018     5.0
# 1                            "Sr Principal Engineer"  Sep 27, 2018     4.0
# 2                               "Good Place to work"  Sep 28, 2018     4.0
# 3  "I enjoy working here, but my compensation is ...  Sep 25, 2018     4.0
# 4                        "Technical Support Manager"  Sep 26, 2018     4.0
#
#      Current/Former              Job Title      Location Recommendation?  \
# 0  Current Employee     Anonymous Employee           NaN             NaN
# 1  Current Employee              Architect    Austin, TX      Recommends
# 2  Current Employee     Anonymous Employee           NaN             NaN
# 3  Current Employee  Senior Representative  Franklin, MA      Recommends
# 4   Former Employee     Anonymous Employee           NaN      Recommends
#
#             Outlook                                          Main Text  \
# 0               NaN              I have been working at Dell full-time
# 1  Positive Outlook  Oct 2, 2018 – Candidate and Employee Experienc...
# 2               NaN                                                NaN
# 3   Neutral Outlook  I have been working at Dell full-time (More th...
# 4  Positive Outlook                         I worked at Dell part-time
#
#                                                 Pros  \
# 0                 Company culture, work life balance
# 1                              Good work environment
# 2  Flexibility in work, Friendly environment,scop...
# 3  I like my job, I have a lot of responsibility,...
# 4                  Competitive salary, great culture
#
#                                                 Cons  \
# 0  High achieving individuals may feel underemployed
# 1                                 Slow career growth
# 2  Lack of communication gap between team members...
# 3  My pay does not reflect the level of difficult...
# 4  Career growth limited at the management level ...
#
#                                 Advice to management  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  I would like more opportunities for growth in ...
# 4  promote more african Americans to senior manag...
#
#                                           pros_clean  \
# 0            [company, culture, work, life, balance]
# 1                          [good, work, environment]
# 2  [flexibility, work, friendly, environment, sco...
# 3  [like, job, lot, responsibility, work, good, p...
# 4              [competitive, salary, great, culture]
#
#                                           cons_clean
# 0  [high, achieving, individuals, may, feel, unde...
# 1                             [slow, career, growth]
# 2  [lack, communication, gap, team, members, mana...
# 3  [pay, reflect, level, difficulty, responsibili...
# 4  [career, growth, limited, management, level, u...

# %% [markdown]
# ### Step 2: get pros/cons attributes

# %%
#manually took some attributes from the top frequent pros words
pros_attribute = ['great','good','happy','nice','decent','excellent','best','ethical','strong','flexible','new',
                  'easy','friendly','positive','different','professional','high','solid','corporate',
                  'smart','stable','large']

# %%
#manually took some attributes from the top frequent cons words
cons_attribute = ['low','little','hard','difficult','long','poor','limited','bad','slow','terrible','conservative'
                 ,'horrible','different','less','senior','political','bureaucratic']

# %% [markdown]
# ### Step 3: lemmentize -> get replacement

# %%
replacement = {'work_life_balance':['time','life','balance','sabbatical','sabbaticals','focus','hour','day','health','flexible','week'
                                    ,'vacation','schedule','overtime'],
                'culture_value':['people','culture','team','care','value','product','coworkers','atmosphere','competitive'
                                ,'family','collaboration','respect','community','colleague','supportive','vision','diversity'],
                'career_oppotunity':['opportunity','learn','industry','career','license','training','train','growth','grow'
                                    ,'level','position','development','advancement','advance','study','build','skill','resource'
                                    ,'education','potential'],
                'company_benefit':['company','benefit','pay','financial','financially','provide','salary','bonus','offer'
                                  ,'401k','package','stock','compensation','invest','investment','money','performance','reward'
                                  ,'retirement','promote','insurance'],
                'senior_management':['place','environment','management','help','manager','experience','match'
                                                ,'plan','office','support','location','leadership','treat','helpful','senior'
                                                ,'manage','leader','communication']}

# %%
def getKeysByValue(dictOfElements, valueToFind):
    for k,v  in dictOfElements.items():
        if valueToFind in v:
            return(k)
    return  valueToFind

def replace_attributes(s):
    return([getKeysByValue(replacement,y) for y in s])

# %%
dell_data['pros_replace'] = dell_data['pros_clean'].map(replace_attributes)
dell_data['cons_replace'] = dell_data['cons_clean'].map(replace_attributes)

# %% [markdown]
# ### Step 4: Lift Score

# %%
def ratio(x,y):
    if x==0:
        return float(y)
    if y==0:
        return float(x)
    return(float(x)*float(y))

def get_lift(a,b,tokenized_data):
    '''Function to calculate lift scores given any two words from a list of tokenized words'''
    if (a==b):
        return 1
    p_a = len([i for i in tokenized_data if a in i])
    p_b = len([i for i in tokenized_data if (b in i)])
    p_a_b = len([i for i in tokenized_data if a in i if b in i])
    n = len(tokenized_data)
    return float(float(n)*float(p_a_b)/ratio(p_a,p_b))

# %%
pros_list = replacement.keys()
lift_score = [get_lift(x,y,dell_data.pros_replace) for x in pros_attribute for y in pros_list]
formatted_lift_score = [ round(elem,2) for elem in lift_score ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(pros_attribute),len(pros_list))),index =pros_attribute , columns = pros_list )
# Out:
#               culture_value  company_benefit  senior_management  \
# great                  1.45             1.15               1.38
# good                   1.09             1.29               1.14
# happy                  1.72             1.42               1.38
# nice                   1.56             1.01               1.57
# decent                 1.02             2.32               0.99
# excellent              1.33             1.35               1.30
# best                   1.17             1.29               1.48
# ethical                1.07             1.82               1.10
# strong                 1.41             1.35               1.23
# flexible               0.00             0.00               0.00
# new                    0.97             1.26               1.26
# easy                   1.38             1.24               1.22
# friendly               1.59             0.71               1.80
# positive               1.73             1.15               1.46
# different              1.18             1.12               1.15
# professional           1.41             0.80               1.57
# high                   1.07             1.48               1.38
# solid                  1.41             2.01               1.24
# corporate              1.69             1.54               1.55
# smart                  2.85             0.80               1.03
# stable                 0.74             1.82               0.86
# large                  0.98             2.22               0.99
#
#               work_life_balance  career_oppotunity
# great                      1.10               1.18
# good                       1.18               0.99
# happy                      1.02               0.53
# nice                       0.95               0.72
# decent                     1.49               1.32
# excellent                  1.16               1.42
# best                       0.95               1.27
# ethical                    0.81               1.05
# strong                     1.00               1.51
# flexible                   0.00               0.00
# new                        0.89               2.20
# easy                       1.31               1.28
# friendly                   0.99               0.87
# positive                   1.00               1.05
# different                  0.78               2.50
# professional               0.91               1.84
# high                       0.72               1.66
# solid                      0.93               1.95
# corporate                  1.11               1.83
# smart                      0.81               1.27
# stable                     0.73               0.65
# large                      0.69               1.49

# %%
cons_list = replacement.keys()
lift_score = [get_lift(x,y,dell_data.cons_replace) for x in cons_attribute for y in cons_list]
formatted_lift_score = [ round(elem,2) for elem in lift_score ]

# %%
pd.DataFrame(reshape(formatted_lift_score,(len(cons_attribute),len(cons_list))),index =cons_attribute , columns = cons_list )
# Out:
#               culture_value  company_benefit  senior_management  \
# low                    1.28             2.44               1.12
# little                 1.46             1.03               1.42
# hard                   1.19             1.24               1.18
# difficult              1.24             1.20               1.33
# long                   1.42             1.05               1.26
# poor                   1.39             1.24               2.21
# limited                1.16             1.09               1.01
# bad                    1.56             1.18               1.78
# slow                   0.66             1.08               0.72
# terrible               1.92             1.65               2.50
# conservative           2.80             1.30               1.29
# horrible               1.91             1.60               1.66
# different              1.62             1.35               1.51
# less                   1.15             1.67               0.71
# senior                 0.00             0.00               0.00
# political              1.71             0.89               1.90
# bureaucratic           0.94             1.17               1.16
#
#               work_life_balance  career_oppotunity
# low                        1.19               1.47
# little                     1.29               1.55
# hard                       1.25               1.42
# difficult                  1.48               1.69
# long                       2.40               1.11
# poor                       1.31               1.23
# limited                    0.92               3.35
# bad                        1.03               1.03
# slow                       0.77               2.48
# terrible                   0.90               1.53
# conservative               0.84               0.63
# horrible                   2.17               0.70
# different                  1.77               1.38
# less                       0.98               1.55
# senior                     0.00               0.00
# political                  0.87               1.38
# bureaucratic               1.39               0.75
