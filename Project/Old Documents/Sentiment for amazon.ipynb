# %%
import pandas as pd
import re,string
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib.pyplot as plt
import warnings
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("Scraper/amazon.csv")
print(df.dtypes)
print(df.shape)
# Out:
# Title                    object
# Date Written             object
# Rating                  float64
# Current/Former           object
# Job Title                object
# Location                 object
# Recommendation?          object
# Outlook                  object
# Main Text                object
# Pros                     object
# Cons                     object
# Advice to management     object
# dtype: object
# (25056, 12)

# %%
#df.columns = 
df.columns = ['title', 'date_written', 'rating', 'current_former', 'job_title',
       'location', 'recommendation', 'outlook', 'main_text', 'pros', 'cons',
       'advice_to_management']

# %%
df.head()
# Out:
#                                                title date_written  rating  \
# 0                                  "Account Manager"  Sep 9, 2018     3.0
# 1  "All the "bad" things you heard about Amazon i...  Sep 9, 2018     1.0
# 2      "Amazon is giving hard time to the employees"  Sep 9, 2018     1.0
# 3                       "Amazon Warehouse Operative"  Sep 9, 2018     1.0
# 4  "Amazon was the easiest job and I was surround...  Sep 9, 2018     5.0
#
#      current_former           job_title           location     recommendation  \
# 0   Former Employee  Anonymous Employee                NaN         Recommends
# 1   Former Employee  Software Developer        Seattle, WA  Doesn't Recommend
# 2  Current Employee    Fruad Prevention  Hyderabad (India)  Doesn't Recommend
# 3  Current Employee  Anonymous Employee                NaN  Doesn't Recommend
# 4   Former Employee           Associate          Essex, MD         Recommends
#
#             outlook                                        main_text  \
# 0               NaN             - Fun environment and excellent team
# 1  Negative Outlook  I worked at Amazon full-time (More than a year)
# 2  Negative Outlook                        Becoming worst day by day
# 3  Negative Outlook          I have been working at Amazon full-time
# 4  Positive Outlook  I worked at Amazon full-time (Less than a year)
#
#                                                 pros  \
# 0                               - Proactive scenario
# 1                    You get to work a LOT of hours.
# 2  All I can say is Amazon has been changed drast...
# 3                              Weekly pay was a plus
# 4  Fun, easy, positive energy, surrounded by cool...
#
#                                                 cons advice_to_management
# 0  Almost none opportunities to grow or to move t...                  NaN
# 1  Work life balance is extremely bad. Work here ...             Hopeless
# 2                       Working at Amazon is the con                  NaN
# 3  Treated as a number, long hours and no flexibi...    Treat staff equal
# 4               Long hours but you’ll get used to it                  NaN

# %%
#combining pros and cons and cleaning it up
df['pc']= df.pros + ' ' + df.cons

# %%
df.pc = df.pc.astype(str)

# %%
stop = set(stopwords.words('english'))
punc = string.punctuation    

def clean_tokenize(s):
    s = re.sub(r'[^\w\s]', '',s)
    return([word for word in word_tokenize(s.lower()) if word not in stop if word not in punc])

df['pc_clean'] = df.pc.apply(clean_tokenize)
df["pc_cunique"] = df.pc_clean.map(lambda x: sorted(set(x)))

# %% [markdown]
# ## Word cloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = df.pc.sum()

# %%
stop = set(STOPWORDS)
stop.update(['amazon','Amazon','lot','employee','job'])
wordcloud = WordCloud(stopwords=stop, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("amazon.png")

# %% [markdown]
# ## Cosine similarity of reviews and values

# %%
#Following are the amazon values:
c1 = """Customer Obsession. Leaders start with the customer and work backwards. They work vigorously to earn and keep customer trust. Although leaders pay attention to competitors, they obsess over customers. Ownership
Leaders are owners. They think long term and don’t sacrifice long-term value for short-term results. They act on behalf of the entire company, beyond just their own team. They never say that’s not my job. 
"""

c2 = """Insist on the Highest Standards
Leaders have relentlessly high standards - many people may think these standards are unreasonably high. Leaders are continually raising the bar and drive their teams to deliver high quality products, services and processes. Leaders ensure that defects do not get sent down the line and that problems are fixed so they stay fixed."""

# %%
x= df.pc_cunique[0]
' '.join(x)
# type(df.pc_cunique[0])
# type(values)
# Out:
# 'almost another grow move none opportunities proactive scenario team'

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
df['stemmed'] = df['pc'].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
df.stemmed.head()
# Out:
# 0    - proactiv scenario almost none opportun to gr...
# 1    you get to work a lot of hours. work life bala...
# 2    all i can say is amazon has been chang drastic...
# 3    week pay was a plus treat as a number, long ho...
# 4    fun, easy, posit energy, surround by cool peop...
# Name: stemmed, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

cvec = CountVectorizer(stop_words='english', min_df=1, max_df=.5, ngram_range=(1,2))
cvec
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.5, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
from itertools import islice
cvec.fit(df.stemmed)
list(islice(cvec.vocabulary_.items(), 20))
# Out:
# [('proactiv', 161950),
#  ('scenario', 180920),
#  ('opportun', 142637),
#  ('grow', 89313),
#  ('anoth', 10716),
#  ('team', 201486),
#  ('proactiv scenario', 161966),
#  ('scenario opportun', 180927),
#  ('opportun grow', 142877),
#  ('grow anoth', 89330),
#  ('anoth team', 10818),
#  ('lot', 121807),
#  ('hours', 98306),
#  ('life', 117026),
#  ('balanc', 17642),
#  ('extrem', 74386),
#  ('bad', 17127),
#  ('plan', 156030),
#  ('unhappi', 214412),
#  ('miserable', 132257)]

# %%
cvec = CountVectorizer(stop_words='english', min_df=.0025, max_df=.1, ngram_range=(1,2))
cvec.fit(df.stemmed)
len(cvec.vocabulary_)
# Out:
# 1313

# %%
cvec_counts = cvec.transform(df.stemmed)
print('sparse matrix shape:', cvec_counts.shape)
print('nonzero count:', cvec_counts.nnz)
print('sparsity: %.2f%%' % (100.0 * cvec_counts.nnz / (cvec_counts.shape[0] * cvec_counts.shape[1])))
# Out:
# sparse matrix shape: (25056, 1313)
# nonzero count: 329232
# sparsity: 1.00%

# %%
occ = np.asarray(cvec_counts.sum(axis=0)).ravel().tolist()
counts_df = pd.DataFrame({'term': cvec.get_feature_names(), 'occurrences': occ})
counts_df.sort_values(by='occurrences', ascending=False).head(20)
# Out:
#           term  occurrences
# 259        day         3117
# 1122      team         3025
# 870      place         2590
# 789   opportun         2582
# 335    employe         2552
# 660       long         2515
# 105    benefit         2505
# 646       like         2499
# 509       hard         2384
# 690       make         2325
# 642       life         2250
# 525       high         2114
# 396       fast         2105
# 944     realli         1874
# 350    environ         1860
# 707       mani         1754
# 500     growth         1716
# 756        new         1713
# 300        don         1683
# 241     cultur         1663

# %%
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(cvec_counts)
transformed_weights
# Out:
# <25056x1313 sparse matrix of type '<class 'numpy.float64'>'
# 	with 329232 stored elements in Compressed Sparse Row format>

# %%
weights = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)
# Out:
#            term    weight
# 1122       team  0.019147
# 105     benefit  0.018890
# 259         day  0.018432
# 870       place  0.018319
# 660        long  0.017666
# 789    opportun  0.017195
# 642        life  0.016888
# 335     employe  0.016831
# 509        hard  0.016201
# 350     environ  0.016076
# 396        fast  0.015218
# 646        like  0.015183
# 525        high  0.014676
# 241      cultur  0.014337
# 500      growth  0.014148
# 93       balanc  0.014117
# 690        make  0.013829
# 1274  work life  0.013757
# 944      realli  0.013010
# 111    benefits  0.012464

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse.csr import csr_matrix #need this if you want to save tfidf_matrix

tf = TfidfVectorizer(analyzer='word', ngram_range=(1,6),min_df = 0, stop_words = 'english')

#tf = TfidfVectorizer(ngram_range=(1,3), min_df = 0, stop_words = 'english')
#tf = TfidfVectorizer()
#pc_list = df.pc_cunique.map(lambda x : ' '.join(x))

# %%
tfidf_matrix =  tf.fit_transform(df['pc'])
tfidf_matrix.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-aa0ee0c7e14e> in <module>()
#       1 tfidf_matrix =  tf.fit_transform(df['pc'])
# ----> 2 tfidf_matrix.toarray()
#
# ~\Anaconda2\envs\Python3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#     945         if out is None and order is None:
#     946             order = self._swap('cf')[0]
# --> 947         out = self._process_toarray_args(order, out)
#     948         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     949             raise ValueError('Output array must be C or F contiguous')
#
# ~\Anaconda2\envs\Python3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1182             return out
#    1183         else:
# -> 1184             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1185
#    1186
#
# MemoryError:

# %%
pc_list = df.pc_cunique.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-edc29209fc1e> in <module>()
# ----> 1 pc_list = df.pc_cunique.sum()
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pc_cunique'

# %%
def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])
    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
    return 0.0
    else:
    return float(numerator) / denominator

# %%
from collections import Counter

def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)

WORD = re.compile(r'\w+')

text1 = df["pc_cunique"]
text2= values
#print(text_to_vector(text1))
print(text_to_vector(text2))
# Out:
# Counter({'and': 4, 'the': 2, 'Customer': 1, 'Obsession': 1, 'Ownership': 1, 'Invent': 1, 'Simplify': 1, 'Are': 1, 'Right': 1, 'A': 1, 'Lot': 1, 'Learn': 1, 'Be': 1, 'Curious': 1, 'Hire': 1, 'Develop': 1, 'Best': 1, 'Insist': 1, 'on': 1, 'Highest': 1, 'Standards': 1, 'Think': 1, 'BigBias': 1, 'for': 1, 'Action': 1, 'Frugality': 1, 'Earn': 1, 'Trust': 1, 'Dive': 1, 'Deep': 1, 'Have': 1, 'Backbone': 1, 'Disagree': 1, 'Commit': 1, 'Deliver': 1, 'Results': 1})

# %%
weights = tvec_weights.toarray()
weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
weights_df.head()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-32-f89d28124004> in <module>()
#       1 weights = tvec_weights.toarray()
# ----> 2 weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
#       3 weights_df.head()
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
# -> 7359     arrays = _homogenize(arrays, index, dtype)
#    7360
#    7361     # from BlockManager perspective
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\frame.py in _homogenize(data, index, dtype)
#    7667                 v = lib.fast_multiget(v, oindex.values, default=np.nan)
#    7668             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 7669                                 raise_cast_failure=False)
#    7670
#    7671         homogenized.append(v)
#
# ~\Anaconda2\envs\Python3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4163     elif subarr.ndim > 1:
#    4164         if isinstance(data, np.ndarray):
# -> 4165             raise Exception('Data must be 1-dimensional')
#    4166         else:
#    4167             subarr = com._asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
def get_postings_and_reverse_postings(document):
    """Read filename and populate the word_freq and reverse_postings dictionary"""
    reverse_postings = {}
    postings = {}

    for word in document:
        postings[word] = {}
        if word in postings[full_quote]:
            postings[full_quote][word] += 1
        else:
            postings[full_quote][word] = 1
        
        if word in reverse_postings:
            if full_quote in reverse_postings[word]:
                    reverse_postings[word][full_quote] += 1
                else:
                    reverse_postings[word][full_quote] = 1
            else:
                reverse_postings[word] = {full_quote:1}

    return postings, reverse_postings

# %%
def tfidf(word, full_quote, postings, reverse_postings):
    max_freq = -1
    for w, freq in postings[full_quote].iteritems():
        if freq > max_freq:
            max_freq = freq
    tf = 1.0 * postings[full_quote][word] / max_freq
    
    doc_freq_for_word = len(reverse_postings[word])
    N = len(postings.keys())
    idf = math.log(float(N) / doc_freq_for_word)
    
    tfidf = tf * idf
    print('tf={} idf={} tfidf={} N={} df={}'.format(tf, idf, tfidf, N, doc_freq_for_word))
    return tfidf

# %%
document = df.pc_clean.sum()

# %%
document
# Out:
# ['proactive',
#  'scenario',
#  'almost',
#  'none',
#  'opportunities',
#  'grow',
#  'move',
#  'another',
#  'team',
#  'get',
#  'work',
#  'lot',
#  'hours',
#  'work',
#  'life',
#  'balance',
#  'extremely',
#  'bad',
#  'work',
#  'plan',
#  'unhappy',
#  'miserable',
#  'crying',
#  'desk',
#  'everyday',
#  'exaggeration',
#  'amazon',
#  'squeeze',
#  'every',
#  'drop',
#  'life',
#  'say',
#  'amazon',
#  'changed',
#  'drastically',
#  'trying',
#  'implement',
#  'cost',
#  'cutting',
#  'everything',
#  'implementing',
#  'hsbc',
#  'policies',
#  'working',
#  'amazon',
#  'con',
#  'weekly',
#  'pay',
#  'plus',
#  'treated',
#  'number',
#  'long',
#  'hours',
#  'flexibility',
#  'work',
#  'fun',
#  'easy',
#  'positive',
#  'energy',
#  'surrounded',
#  'cool',
#  'people',
#  'long',
#  'hours',
#  'youll',
#  'get',
#  'used',
#  'worked',
#  'really',
#  'wonderful',
#  'hardworker',
#  'miss',
#  'push',
#  'number',
#  'daunting',
#  'managers',
#  'need',
#  'bit',
#  'compassion',
#  'get',
#  'learn',
#  'manythings',
#  'growth',
#  'slow',
#  'fair',
#  'good',
#  'environment',
#  'friendly',
#  'people',
#  'easy',
#  'work',
#  'less',
#  'growth',
#  'oppurtunities',
#  'easy',
#  'change',
#  'policies',
#  'good',
#  'experience',
#  'colleagues',
#  'managers',
#  'snacks',
#  'great',
#  'pay',
#  'little',
#  'experience',
#  'advance',
#  'degree',
#  'lots',
#  'hours',
#  'winter',
#  'time',
#  'takes',
#  'year',
#  'plus',
#  'actually',
#  'advance',
#  'company',
#  'best',
#  'engineers',
#  'around',
#  'learn',
#  'theres',
#  'sometimes',
#  'much',
#  'pressure',
#  'coming',
#  'short',
#  'term',
#  'solution',
#  'salaried',
#  'positions',
#  'pay',
#  'well',
#  'good',
#  'stock',
#  'awards',
#  'hire',
#  'position',
#  'externally',
#  'entirely',
#  'possible',
#  'begin',
#  'seasonal',
#  'employee',
#  'promote',
#  'senior',
#  'operational',
#  'management',
#  'fulfillment',
#  'center',
#  'hired',
#  'internally',
#  'ie',
#  'promoted',
#  'paid',
#  'less',
#  'receive',
#  'fewer',
#  'stock',
#  'awards',
#  'external',
#  'hires',
#  'learn',
#  'lot',
#  'work',
#  'super',
#  'tech',
#  'limited',
#  'visibility',
#  'retail',
#  'systems',
#  'home',
#  'office',
#  'holidays',
#  'company',
#  'culture',
#  'much',
#  'work',
#  'unstructured',
#  'strategy',
#  'decent',
#  'pay',
#  'lots',
#  'hours',
#  'great',
#  'opportunity',
#  'advancement',
#  'given',
#  'right',
#  'timing',
#  'bugging',
#  'management',
#  'management',
#  'switching',
#  'shifts',
#  'lack',
#  'coordination',
#  'make',
#  'job',
#  'nightmare',
#  'create',
#  'metrics',
#  'dependent',
#  'catch',
#  'dysfunctional',
#  'job',
#  'routine',
#  'easy',
#  'fast',
#  'job',
#  'get',
#  'working',
#  'distribution',
#  'center',
#  'long',
#  'hours',
#  'limited',
#  'break',
#  'time',
#  'job',
#  'pays',
#  'minimal',
#  'non',
#  'professional',
#  'management',
#  'riddled',
#  'favoritism',
#  'people',
#  'skills',
#  'highly',
#  'skilled',
#  'capable',
#  'team',
#  'members',
#  'minimal',
#  'work',
#  'life',
#  'balance',
#  'plenty',
#  'paid',
#  'time',
#  'vaction',
#  'many',
#  'chiefs',
#  'amount',
#  'indians',
#  'much',
#  'invent',
#  'innovate',
#  'limited',
#  'added',
#  'benefits',
#  '10',
#  'website',
#  'get',
#  'job',
#  'little',
#  'entry',
#  'requirements',
#  'easy',
#  'pays',
#  'relatively',
#  'well',
#  'work',
#  'required',
#  'job',
#  'give',
#  'many',
#  'hours',
#  'frequently',
#  'requires',
#  'stay',
#  'extra',
#  'hour',
#  'physically',
#  'strenuous',
#  'best',
#  'reason',
#  'work',
#  'earn',
#  'money',
#  'cant',
#  'count',
#  'constoo',
#  'many',
#  'customer',
#  'whole',
#  'focus',
#  'make',
#  'way',
#  'accountability',
#  'ownership',
#  'lacking',
#  'good',
#  'salary',
#  'benefits',
#  'including',
#  'stocks',
#  'personnel',
#  'operational',
#  'support',
#  'new',
#  'amazonians',
#  'really',
#  'depends',
#  'manager',
#  'team',
#  'much',
#  'enjoy',
#  'work',
#  'excellent',
#  '401k',
#  'contribution',
#  'matching',
#  'profit',
#  'sharing',
#  'high',
#  'retention',
#  'support',
#  'employees',
#  'awards',
#  'employees',
#  'yearly',
#  'employee',
#  'christmas',
#  'party',
#  'various',
#  'activities',
#  'throughout',
#  'year',
#  'difficulty',
#  'obtaining',
#  'higher',
#  'level',
#  'management',
#  'team',
#  'internal',
#  'employees',
#  'often',
#  'outside',
#  'selections',
#  'preferred',
#  'rather',
#  'promotion',
#  'subordinates',
#  'great',
#  'benefits',
#  'starting',
#  'day',
#  'one',
#  'work',
#  'life',
#  'balance',
#  'throw',
#  'overtime',
#  'drop',
#  'dime',
#  'management',
#  'trained',
#  'well',
#  'safety',
#  'department',
#  'run',
#  'people',
#  'prejudice',
#  'dont',
#  'care',
#  'safety',
#  'employees',
#  'care',
#  'production',
#  'u',
#  'dont',
#  'work',
#  'fast',
#  'enough',
#  'written',
#  'provide',
#  'light',
#  'duty',
#  'injured',
#  'employees',
#  'good',
#  'base',
#  'pay',
#  'compared',
#  'recruiting',
#  'coordinator',
#  'jobs',
#  'area',
#  'long',
#  'hours',
#  'good',
#  'salary',
#  'makes',
#  'want',
#  'keep',
#  'working',
#  'houses',
#  'expensive',
#  'seattle',
#  'amazon',
#  'fast',
#  'pace',
#  'stressful',
#  'times',
#  'jeff',
#  'bezos',
#  'animal',
#  'sure',
#  'demanding',
#  'thats',
#  'hes',
#  'billionaire',
#  'great',
#  'place',
#  'work',
#  'grow',
#  'none',
#  'great',
#  'exposure',
#  'learning',
#  'good',
#  'salary',
#  'work',
#  'culture',
#  'good',
#  'work',
#  'life',
#  'balance',
#  'little',
#  'nice',
#  'environment',
#  'honestly',
#  'great',
#  'place',
#  'work',
#  'good',
#  'starting',
#  'pay',
#  'overnight',
#  'differential',
#  'great',
#  'hours',
#  'flexible',
#  'scheduling',
#  'overtime',
#  'opportunities',
#  'lunch',
#  'break',
#  'room',
#  'food',
#  'options',
#  'sometimes',
#  'company',
#  'bonus',
#  'warehouse',
#  'great',
#  'together',
#  'month',
#  'short',
#  'lunch',
#  'rest',
#  'breaks',
#  'meet',
#  'rate',
#  'disliked',
#  'also',
#  'available',
#  'lockers',
#  'leave',
#  'phone',
#  'inside',
#  'break',
#  'room',
#  'people',
#  'easily',
#  'take',
#  'though',
#  'never',
#  'took',
#  'theres',
#  'cameras',
#  'everywhere',
#  'great',
#  'place',
#  'work',
#  'amazing',
#  'none',
#  'amazing',
#  'amzing',
#  'flexible',
#  'shift',
#  'timings',
#  'benefits',
#  'work',
#  'culture',
#  'sucks',
#  'finance',
#  'otherwise',
#  'great',
#  'work',
#  'culture',
#  'domain',
#  'work',
#  'icqa',
#  'inventory',
#  'control',
#  'quality',
#  'assurance',
#  'love',
#  'job',
#  'department',
#  'numerous',
#  'paths',
#  'ambassador',
#  'problem',
#  'solver',
#  'auditor',
#  'counter',
#  'damage',
#  'processor',
#  'love',
#  'able',
#  'navigate',
#  'called',
#  'duty',
#  'within',
#  'department',
#  'also',
#  'opportunity',
#  'pack',
#  'hand',
#  'slam',
#  'gift',
#  'wrap',
#  'needed',
#  'enjoyed',
#  'well',
#  'noisy',
#  'atmosphere',
#  'warehouse',
#  'pretty',
#  'much',
#  'expected',
#  'good',
#  'pay',
#  'given',
#  'hectic',
#  'life',
#  'work',
#  'life',
#  'balance',
#  'working',
#  'one',
#  'big',
#  '5',
#  'tech',
#  'benefits',
#  'salary',
#  'health',
#  'insurance',
#  '2',
#  '401k',
#  'match',
#  'compared',
#  'companies',
#  'worked',
#  '6',
#  'amazon',
#  '2nd',
#  'worst',
#  'comes',
#  'benefits',
#  'good',
#  'rate',
#  'pay',
#  'uncomfortable',
#  'foot',
#  'wear',
#  'paid',
#  'time',
#  'bi',
#  'weekly',
#  'run',
#  'like',
#  'hell',
#  'monthly',
#  'bonus',
#  'based',
#  'partially',
#  'attendance',
#  'feet',
#  '10',
#  'hours',
#  'days',
#  'gives',
#  'great',
#  'flexibility',
#  'work',
#  'around',
#  'world',
#  'without',
#  'restrictions',
#  'gives',
#  'great',
#  'environment',
#  'work',
#  'spend',
#  'time',
#  'working',
#  'multi',
#  'time',
#  'zones',
#  'might',
#  'end',
#  'tight',
#  'schedule',
#  'quite',
#  'often',
#  '1',
#  'good',
#  'place',
#  'start',
#  'career',
#  '1',
#  'hard',
#  'get',
#  'started',
#  'lot',
#  'new',
#  'stuff',
#  'needed',
#  'learned',
#  'good',
#  'pay',
#  'relocation',
#  'assistance',
#  'interns',
#  'fast',
#  'paced',
#  'environment',
#  'entire',
#  'management',
#  'team',
#  'even',
#  'beyond',
#  'manager',
#  'supportive',
#  'gave',
#  'great',
#  'guidance',
#  'advice',
#  'successful',
#  'area',
#  'manager',
#  'skills',
#  'learned',
#  'include',
#  'multitasking',
#  'quick',
#  'analysis',
#  'prioritization',
#  'effectively',
#  'managingleading',
#  'team',
#  'little',
#  'structure',
#  'guidance',
#  'required',
#  'project',
#  'struggled',
#  'find',
#  'appropriate',
#  'topic',
#  'given',
#  'intern',
#  'time',
#  'frame',
#  'skill',
#  'level',
#  'ended',
#  'project',
#  'work',
#  'home',
#  'little',
#  'time',
#  'work',
#  'work',
#  'day',
#  'warehouses',
#  'generally',
#  'arent',
#  'big',
#  'cities',
#  'hard',
#  'start',
#  'dont',
#  'know',
#  'anyone',
#  'area',
#  'project',
#  'job',
#  'isnt',
#  'mentally',
#  'stimulating',
#  'great',
#  'leadership',
#  'entrepreneurial',
#  'constant',
#  'change',
#  'continuous',
#  'improvement',
#  'compensation',
#  'good',
#  'work',
#  'lot',
#  'experienced',
#  'managers',
#  'learn',
#  'learned',
#  'lot',
#  'two',
#  'years',
#  'amazon',
#  'poor',
#  'treatment',
#  'associates',
#  'managers',
#  'hours',
#  '60',
#  'week',
#  'rack',
#  'stack',
#  'performance',
#  'evaluations',
#  'managers',
#  'poor',
#  'worklife',
#  'balance',
#  'able',
#  'work',
#  'different',
#  'departments',
#  'good',
#  'health',
#  'care',
#  'always',
#  'overtime',
#  'treat',
#  'like',
#  'number',
#  'good',
#  'idea',
#  'long',
#  'term',
#  'job',
#  'decent',
#  'pay',
#  'management',
#  'horrible',
#  'amazon',
#  'offers',
#  'excellent',
#  'benefits',
#  'package',
#  'employees',
#  'room',
#  'advancement',
#  'lack',
#  'ability',
#  'provide',
#  'proper',
#  'training',
#  'associates',
#  'every',
#  'level',
#  'also',
#  'lack',
#  'communication',
#  'within',
#  'company',
#  'whole',
#  'trickles',
#  'individual',
#  'sites',
#  'fun',
#  'face',
#  'paced',
#  'covered',
#  'distribution',
#  'activities',
#  'one',
#  'job',
#  'title',
#  'lots',
#  'experience',
#  'strict',
#  'absence',
#  'policy',
#  'sick',
#  'leave',
#  'good',
#  'pay',
#  'much',
#  'work',
#  'load',
#  'good',
#  'quality',
#  'work',
#  'team',
#  'much',
#  'worklife',
#  'balance',
#  'low',
#  'common',
#  'every',
#  'comapany',
#  'like',
#  'amazon',
#  'great',
#  'work',
#  'culture',
#  'people',
#  'certain',
#  'period',
#  'work',
#  'gets',
#  'monotonous',
#  'good',
#  'work',
#  'life',
#  'balance',
#  'good',
#  'cointerns',
#  'learnt',
#  'lot',
#  'probably',
#  'challenging',
#  'work',
#  'fast',
#  'paced',
#  'lots',
#  'room',
#  'growth',
#  'ability',
#  'lead',
#  'large',
#  'teams',
#  'great',
#  'associates',
#  'generally',
#  'hires',
#  'great',
#  'smart',
#  'managers',
#  'senior',
#  'management',
#  'seems',
#  'disconnected',
#  'daily',
#  'operations',
#  'business',
#  'outside',
#  'certain',
#  'metrics',
#  'great',
#  'place',
#  'work',
#  'comes',
#  'pay',
#  'benefits',
#  'provide',
#  'also',
#  'allow',
#  'overtime',
#  'constant',
#  'fast',
#  'pace',
#  'downtime',
#  'quota',
#  'must',
#  'reach',
#  'day',
#  'youre',
#  'gone',
#  'also',
#  'dont',
#  'give',
#  'directions',
#  'clearly',
#  'sometimes',
#  'make',
#  'think',
#  'youre',
#  'right',
#  'find',
#  'isnt',
#  'always',
#  'hiring',
#  'easy',
#  'get',
#  'job',
#  'pays',
#  'better',
#  'entry',
#  'level',
#  'jobs',
#  'possibility',
#  'move',
#  'tier',
#  '3',
#  'work',
#  '10',
#  'times',
#  'harder',
#  'entry',
#  'level',
#  'job',
#  'full',
#  'stack',
#  'development',
#  'good',
#  'ownership',
#  'much',
#  'communication',
#  'work',
#  'done',
#  'sde',
#  'customer',
#  'centric',
#  'company',
#  'love',
#  'everything',
#  'customers',
#  'imbibed',
#  'company',
#  'theres',
#  'cons',
#  'talk',
#  'amazon',
#  'full',
#  'work',
#  'week',
#  'hours',
#  'overtime',
#  'sometimes',
#  '6',
#  'paid',
#  'holidays',
#  'accrue',
#  'paid',
#  'time',
#  'data',
#  'driven',
#  'management',
#  'care',
#  'teams',
#  'high',
#  'turn',
#  'fully',
#  'hired',
#  'incredibly',
#  'difficult',
#  'get',
#  'rid',
#  'bad',
#  'associates',
#  'unrealistic',
#  'expectations',
#  'employees',
#  'used',
#  'love',
#  'coming',
#  'work',
#  'two',
#  'years',
#  'fantastic',
#  'recent',
#  'changes',
#  'managing',
#  'style',
#  'ruined',
#  'great',
#  'place',
#  'work',
#  'place',
#  'leave',
#  'soon',
#  'enough',
#  'lot',
#  'interesting',
#  'work',
#  'smart',
#  'people',
#  'lot',
#  'benefits',
#  'sometimes',
#  'oncall',
#  ...]

# %%
document.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-79489e8b349f> in <module>()
# ----> 1 document.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
document.count('amazon')
# Out:
# 4825

# %%
document['amazon']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-3e95826819b7> in <module>()
# ----> 1 document['amazon']
#
# TypeError: list indices must be integers or slices, not str

# %%
def termFrequency(term, document):
    return document.count(term.lower()) / float(len(document))

def inverseDocumentFrequency(term, allDocuments):
    numDocumentsWithThisTerm = 0
    for doc in allDocuments:
        if term.lower() in allDocuments[doc].lower().split():
            numDocumentsWithThisTerm = numDocumentsWithThisTerm + 1
 
    if numDocumentsWithThisTerm > 0:
        return 1.0 + log(float(len(allDocuments)) / numDocumentsWithThisTerm)
    else:
        return 1.0

# %% [markdown]
# ## Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

def get_sentiment_scores(sentence):
    snt = analyser.polarity_scores(sentence)
    return(snt['compound'])

def get_pos_neg(sentence):
    snt = analyser.polarity_scores(sentence)
    if(snt['pos'] > snt['neg']):
        return('pos')
    return('neg')

# %%
df['sent_score'] = df.pc.map(get_sentiment_scores)
df['pos_neg'] = df.pc.map(get_pos_neg)
df.head()
# Out:
#                                                title date_written  rating  \
# 0                                  "Account Manager"  Sep 9, 2018     3.0
# 1  "All the "bad" things you heard about Amazon i...  Sep 9, 2018     1.0
# 2      "Amazon is giving hard time to the employees"  Sep 9, 2018     1.0
# 3                       "Amazon Warehouse Operative"  Sep 9, 2018     1.0
# 4  "Amazon was the easiest job and I was surround...  Sep 9, 2018     5.0
#
#      current_former           job_title           location     recommendation  \
# 0   Former Employee  Anonymous Employee                NaN         Recommends
# 1   Former Employee  Software Developer        Seattle, WA  Doesn't Recommend
# 2  Current Employee    Fruad Prevention  Hyderabad (India)  Doesn't Recommend
# 3  Current Employee  Anonymous Employee                NaN  Doesn't Recommend
# 4   Former Employee           Associate          Essex, MD         Recommends
#
#             outlook                                        main_text  \
# 0               NaN             - Fun environment and excellent team
# 1  Negative Outlook  I worked at Amazon full-time (More than a year)
# 2  Negative Outlook                        Becoming worst day by day
# 3  Negative Outlook          I have been working at Amazon full-time
# 4  Positive Outlook  I worked at Amazon full-time (Less than a year)
#
#                                                 pros  \
# 0                               - Proactive scenario
# 1                    You get to work a LOT of hours.
# 2  All I can say is Amazon has been changed drast...
# 3                              Weekly pay was a plus
# 4  Fun, easy, positive energy, surrounded by cool...
#
#                                                 cons advice_to_management  \
# 0  Almost none opportunities to grow or to move t...                  NaN
# 1  Work life balance is extremely bad. Work here ...             Hopeless
# 2                       Working at Amazon is the con                  NaN
# 3  Treated as a number, long hours and no flexibi...    Treat staff equal
# 4               Long hours but you’ll get used to it                  NaN
#
#                                                   pc  \
# 0  - Proactive scenario Almost none opportunities...
# 1  You get to work a LOT of hours. Work life bala...
# 2  All I can say is Amazon has been changed drast...
# 3  Weekly pay was a plus Treated as a number, lon...
# 4  Fun, easy, positive energy, surrounded by cool...
#
#                                             pc_clean  \
# 0  [proactive, scenario, almost, none, opportunit...
# 1  [get, work, lot, hours, work, life, balance, e...
# 2  [say, amazon, changed, drastically, trying, im...
# 3  [weekly, pay, plus, treated, number, long, hou...
# 4  [fun, easy, positive, energy, surrounded, cool...
#
#                                           pc_cunique  sent_score pos_neg
# 0  [almost, another, grow, move, none, opportunit...      0.2250     pos
# 1  [amazon, bad, balance, crying, desk, drop, eve...     -0.9412     neg
# 2  [amazon, changed, con, cost, cutting, drastica...      0.2263     pos
# 3  [flexibility, hours, long, number, pay, plus, ...      0.0258     pos
# 4  [cool, easy, energy, fun, get, hours, long, pe...      0.7650     pos

# %%
print(df.groupby('current_former')[['sent_score']].mean())
print(df.groupby('outlook')[['sent_score']].mean())
print(df.groupby('recommendation')[['sent_score']].mean())
# Out:
#                   sent_score
# current_former
# Current Employee    0.465811
# Former Employee     0.388745
#                   sent_score
# outlook
# Negative Outlook    0.166517
# Neutral Outlook     0.363882
# Positive Outlook    0.512006
#                                     sent_score
# recommendation
# Doesn't Recommend                      0.25585
# Recommend 5 day week 8 hours a day     0.00000
# Recommends                             0.53145

# %%
print(df.job_title.value_counts()[:20])
top_designations = df.job_title.value_counts().index[:20]
df[df.job_title.isin(top_designations)].groupby('job_title')[['sent_score']].mean().plot(kind='bar')
# Out:
# Anonymous Employee                  9885
# Warehouse Associate                  653
# Fulfillment Associate                592
# Software Development Engineer        573
# Area Manager                         302
# Software Development Engineer II     269
# Customer Service Associate           246
# Software Development Engineer I      225
# Associate                            217
# Software Engineer                    212
# Picker                               202
# Process Assistant                    178
# Program Manager                      175
# Operations Manager                   174
# CSA                                  171
# Senior Product Manager               165
# Software Development Manager         149
# Manager                              135
# Packer                               131
# Seller Support Associate             130
# Name: job_title, dtype: int64

# %%
print(df.location.value_counts()[:5])
top_locations = df.location.value_counts().index[:5]
df[df.location.isin(top_locations)].groupby('location')['sent_score'].mean().nlargest(10)
#df.groupby('location')['sent_score'].mean().nlargest(10)
# Out:
# Seattle, WA             3862
# Bengaluru (India)       1132
# Hyderabad (India)       1109
# Chennai (India)          633
# London, England (UK)     284
# Name: location, dtype: int64
# location
# Seattle, WA             0.499431
# Hyderabad (India)       0.487939
# Chennai (India)         0.474653
# Bengaluru (India)       0.451013
# London, England (UK)    0.420635
# Name: sent_score, dtype: float64

# %%
df[df.location.isin(top_locations) & df.job_title.isin(top_designations) ].groupby(['location','job_title'])[['sent_score']].mean()
# Out:
#                                                        sent_score
# location             job_title
# Bengaluru (India)    Anonymous Employee                  0.398590
#                      Associate                           0.495457
#                      CSA                                 0.812600
#                      Customer Service Associate          0.869200
#                      Manager                             0.301622
#                      Operations Manager                  0.550236
#                      Process Assistant                   0.784500
#                      Program Manager                     0.328469
#                      Seller Support Associate            0.573355
#                      Senior Product Manager              0.454255
#                      Software Development Engineer       0.299115
#                      Software Development Engineer I     0.387269
#                      Software Development Engineer II    0.519337
#                      Software Development Manager        0.668987
#                      Software Engineer                   0.300613
# Chennai (India)      Anonymous Employee                  0.452101
#                      Associate                           0.629782
#                      Customer Service Associate          0.901700
#                      Manager                             0.428667
#                      Operations Manager                  0.422342
#                      Process Assistant                   0.796100
#                      Program Manager                     0.633637
#                      Seller Support Associate           -0.350750
#                      Software Development Engineer       0.256100
#                      Software Development Engineer I     0.460420
#                      Software Development Engineer II    0.541320
#                      Software Development Manager        0.709600
#                      Software Engineer                  -0.060933
#                      Warehouse Associate                -0.427800
# Hyderabad (India)    Anonymous Employee                  0.489030
# ...                                                           ...
# London, England (UK) Manager                             0.236475
#                      Operations Manager                  0.669050
#                      Packer                             -0.113150
#                      Picker                              0.000000
#                      Program Manager                     0.374667
#                      Senior Product Manager              0.068860
#                      Software Development Engineer       0.341878
#                      Software Development Engineer I     0.603300
#                      Software Development Engineer II    0.523100
#                      Software Development Manager        0.831075
#                      Software Engineer                   0.649125
#                      Warehouse Associate                 0.900700
# Seattle, WA          Anonymous Employee                  0.508740
#                      Area Manager                        0.470600
#                      Associate                           0.624900
#                      CSA                                 0.306075
#                      Customer Service Associate          0.502742
#                      Fulfillment Associate               0.408775
#                      Manager                             0.499074
#                      Operations Manager                  0.483793
#                      Process Assistant                   0.557400
#                      Program Manager                     0.511061
#                      Seller Support Associate            0.380375
#                      Senior Product Manager              0.474728
#                      Software Development Engineer       0.480374
#                      Software Development Engineer I     0.406625
#                      Software Development Engineer II    0.482596
#                      Software Development Manager        0.476099
#                      Software Engineer                   0.401969
#                      Warehouse Associate                 0.407000
#
# [78 rows x 1 columns]
