# %%
import csv
import pandas as pd
import numpy
import re
from nltk.corpus import stopwords
import nltk
from nltk import pos_tag, word_tokenize
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.porter import PorterStemmer

# %%
df = pd.read_csv('edmunds_comments.csv', encoding='UTF-8')

# %%
df.head()
# Out:
#              date         username  \
# 0  b'September 7'       b'dino001'
# 1  b'September 7'       b'circlew'
# 2  b'September 8'       b'qbrozen'
# 3  b'September 9'  b'FlightNurse2'
# 4  b'September 9'    b'roadburner'
#
#                                                 post  \
# 0  b'If they keep it around in next four-five yea...
# 1                            b'2018 430i Gran Coupe'
# 2  b"The lease rate is the factor that stops me c...
# 3  b"circlew said:\nThe lease rate is the factor ...
# 4  b"'17 F150 Crew 2.7; '67 Coronet R/T; '14 Town...
#
#                                               quotes
# 0  b"The lease rate is the factor that stops me c...
# 1  b"show previous quotes\n\n\nThe Stinger is too...
# 2                                                b''
# 3  b'Again, the local dealer are hopeless at best...
# 4  b'Thanks, but I am more than aware of the dist...

# %%
df['post'].iloc[0].lstrip('b')
# Out:
# '\'If they keep it around in next four-five years, I think I will make myself to put on a hazmat suit and visit our friendly Kia dealer (oh, boy are they horrible here, or what) to check it out. It\\\'s got a lot of good stuff, but seems like they are still behind on a few things, such as relationship between power and gas mileage (e.g. BMW 340/440 has similar performance, but much better gas mileage as a daily driver), but with appropriate price difference, those objections and shortcomings are not insurmountable. Biggest thing will be the "first contact" with a sales person. Hope it won\\\'t start from "are you buying it today?", "what can I do to make you take it home?", or "let me wash your BMW - oh, I can\\\'t find the keys", "How about I show you the deal - square one, two, three, four".\''

# %%
for c in (df.columns.values):
    df[c] = df[c].astype(str).str.lstrip('b')

# %%
df.head()
# Out:
#             date        username  \
# 0  'September 7'       'dino001'
# 1  'September 7'       'circlew'
# 2  'September 8'       'qbrozen'
# 3  'September 9'  'FlightNurse2'
# 4  'September 9'    'roadburner'
#
#                                                 post  \
# 0  'If they keep it around in next four-five year...
# 1                             '2018 430i Gran Coupe'
# 2  "The lease rate is the factor that stops me co...
# 3  "circlew said:\nThe lease rate is the factor t...
# 4  "'17 F150 Crew 2.7; '67 Coronet R/T; '14 Town&...
#
#                                               quotes
# 0  "The lease rate is the factor that stops me co...
# 1  "show previous quotes\n\n\nThe Stinger is too ...
# 2                                                 ''
# 3  'Again, the local dealer are hopeless at best(...
# 4  'Thanks, but I am more than aware of the disti...

# %%
model_df = pd.read_csv('models.csv', encoding='ISO-8859-1')
model_df.columns = ['Replace', 'Search']
model_df['Replace'] = model_df['Replace'].str.lower()
model_df['Search'] = model_df['Search'].str.lower()
model_dict = model_df.set_index('Search')['Replace'].to_dict()

# %%
## making a clean message column 
StopWordslist = stopwords.words("english")

def string_process(s):
    s=str(s)
    lower = s.lower()
    for key, value in model_dict.items():
        lower= lower.replace(key, value)
    words = lower.split()
    refined = []
    for i in words:
        if i not in StopWordslist:
            refined.append(re.sub("[^\w]+", "", i))
    sentence = ' '.join([word for word in refined])
    return(sentence)
df['clean_message']=df['post'].map(string_process)

# %%
def tokenize(text):
    tokens = nltk.word_tokenize(text)
    stems = []
    for item in tokens:
        stems.append(PorterStemmer().stem(item))
    return stems

# %%
vect = TfidfVectorizer(min_df = 5, tokenizer=tokenize).fit(df['clean_message']) ## Using our custom Tokenizer function using Stemming

# %%
len(vect.get_feature_names())  ## Total number of unique vocab after removing not-so-useful words
# Out:
# 6437

# %%
X_vectorized = vect.transform(df['clean_message'])

# %%
X_vectorized.toarray
# Out:
# <bound method _cs_matrix.toarray of <12552x6437 sparse matrix of type '<class 'numpy.float64'>'
# 	with 455239 stored elements in Compressed Sparse Row format>>

# %%
#vect.get_feature_names()

# %%
X_vectorized.shape
# Out:
# (12552, 6437)

# %%
doc =0
feature_index = X_vectorized[doc,:].nonzero()[1]
feature_names = vect.get_feature_names()

# %%
feature_index
# Out:
# array([6390, 6317, 6250, 6204, 6161, 5967, 5841, 5782, 5762, 5757, 5645,
#        5549, 5505, 5448, 5411, 5382, 5169, 5141, 5045, 4963, 4708, 4548,
#        4457, 4409, 4274, 4267, 4133, 4091, 4075, 4038, 3939, 3855, 3736,
#        3586, 3509, 3454, 3426, 3314, 3312, 3308, 3231, 3047, 2993, 2979,
#        2977, 2958, 2909, 2739, 2731, 2640, 2601, 2575, 2491, 2480, 2189,
#        2098, 1953, 1831, 1830, 1801, 1647, 1438, 1322, 1271, 1172, 1109,
#        1052, 1039, 1014,  820,  806,  797])

# %%
tfidf_scores = zip(feature_index, [X_vectorized[doc, x] for x in feature_index])

# %%
di = {}
for w, s in [(feature_names[i],s) for (i, s) in tfidf_scores]:
    di[w] = s

# %%
#di = sorted(di, lambda x )
sorted_by_value = sorted(di.items(), key=lambda kv: kv[1], reverse=True)

# %%
di
# Out:
# {'year': 0.06534336970658151,
#  'wont': 0.1168946885893826,
#  'what': 0.21094820641399484,
#  'wash': 0.15267121923451693,
#  'visit': 0.1288079426514008,
#  'two': 0.08916661551078542,
#  'today': 0.09703021528424831,
#  'three': 0.10984345878967453,
#  'think': 0.06231825488991268,
#  'thing': 0.15418337311206495,
#  'take': 0.07843622144030356,
#  'suit': 0.14096746490074283,
#  'stuff': 0.11439753687040602,
#  'still': 0.07625116822597522,
#  'start': 0.09072057857348018,
#  'squar': 0.16494179475876852,
#  'similar': 0.10673615714922538,
#  'show': 0.10244009368335573,
#  'seem': 0.08028566055159515,
#  'sale': 0.09321112796197703,
#  'relationship': 0.15652946795627698,
#  'put': 0.08742064840068924,
#  'price': 0.07032906161272491,
#  'power': 0.08984002553214986,
#  'person': 0.09688202184431895,
#  'perform': 0.08042716033490499,
#  'out': 0.10200292111552793,
#  'one': 0.057524879510272714,
#  'oh': 0.244596320409519,
#  'object': 0.1399389847169012,
#  'next': 0.09128899436778906,
#  'much': 0.06964551686909629,
#  'mileag': 0.2137788168487366,
#  'make': 0.13667572164490516,
#  'lot': 0.07856649970509207,
#  'like': 0.05421562339495405,
#  'let': 0.09799219618342776,
#  'kia': 0.10427923340129558,
#  'key': 0.13281979214082218,
#  'keep': 0.08820964524557857,
#  'it': 0.06191013469795262,
#  'if': 0.1111990752054335,
#  'how': 0.1359576189044434,
#  'horribl': 0.13863709976945354,
#  'hope': 0.10163486000963866,
#  'home': 0.11314411980849605,
#  'here': 0.09415028949172408,
#  'got': 0.08230123685931323,
#  'good': 0.06925378928044265,
#  'ga': 0.21066036921509326,
#  'friendli': 0.17675322903341611,
#  'four': 0.1240443648424252,
#  'first': 0.08577068247831429,
#  'find': 0.08927160973784097,
#  'eg': 0.15583860653517298,
#  'driver': 0.09668594003345445,
#  'differ': 0.07979731844308703,
#  'dealer': 0.07779593399792753,
#  'deal': 0.09401988510980396,
#  'daili': 0.13407437686491597,
#  'contact': 0.13624002796939833,
#  'check': 0.10421088867687514,
#  'cant': 0.08556155445601028,
#  'buy': 0.07599725867303929,
#  'boy': 0.14742627973268144,
#  'bmw': 0.10469015284399734,
#  'biggest': 0.13433393148560227,
#  'better': 0.07281556537103971,
#  'behind': 0.1202557323768612,
#  'around': 0.08944769867686686,
#  'are': 0.12291754361377105,
#  'appropri': 0.15388509456462007}

# %% [markdown]
# ## Analysis of BMW and Lexus

# %%
df["post_clean"] = df.post.apply(lambda x:re.sub(r'[^\w\s]', ' ', x.lower()))
df["post_clean"] = df.post_clean.apply(lambda x:re.sub(r'(\\n+)', ' ', x))
df["post_clean"] = df.post_clean.apply(lambda x:re.sub(r'^b[\'\"\'"\"''\s]', '', x.lower()))
df["post_clean"] = df.post_clean.apply(lambda x:re.sub(r'\s+', ' ', x))

# %%
stop = set(stopwords.words('english'))
punc = string.punctuation
df['post_clean'] = df.post_clean.apply(lambda x: [word for word in word_tokenize(x) if word not in stop])
df['post_clean'] = df['post_clean'].apply(lambda x: [word for word in x if word not in punc])

# %%
df.head()
# Out:
#             date        username  \
# 0  'September 7'       'dino001'
# 1  'September 7'       'circlew'
# 2  'September 8'       'qbrozen'
# 3  'September 9'  'FlightNurse2'
# 4  'September 9'    'roadburner'
#
#                                                 post  \
# 0  'If they keep it around in next four-five year...
# 1                             '2018 430i Gran Coupe'
# 2  "The lease rate is the factor that stops me co...
# 3  "circlew said:\nThe lease rate is the factor t...
# 4  "'17 F150 Crew 2.7; '67 Coronet R/T; '14 Town&...
#
#                                               quotes  \
# 0  "The lease rate is the factor that stops me co...
# 1  "show previous quotes\n\n\nThe Stinger is too ...
# 2                                                 ''
# 3  'Again, the local dealer are hopeless at best(...
# 4  'Thanks, but I am more than aware of the disti...
#
#                                        clean_message  \
# 0  if keep around next fourfive years think make ...
# 1                               2018 430i gran coupe
# 2  the lease rate factor stops cold taking leapnn...
# 3  circlew saidnthe lease rate factor stops cold ...
# 4  17 ford crew 27 67 coronet rt 14 towncountry l...
#
#                                           post_clean
# 0  [keep, around, next, four, five, years, think,...
# 1                          [2018, 430i, gran, coupe]
# 2  [lease, rate, factor, stops, cold, taking, lea...
# 3  [circlew, said, nthe, lease, rate, factor, sto...
# 4  [17, f150, crew, 2, 7, 67, coronet, r, 14, tow...

# %%
def classifyBMWLex(po):
    """ Classigying dataframe observations containing/not containing BMW"""
    r = 0
    for w in po:
        if((w == 'bmw') | (w == 'lexus')):
            r= 1
    return r

# %%
df['BMW or Lexus post'] = df['post_clean'].map(classifyBMWLex)

# %%
df_bmw_lex = df[df['BMW or Lexus post'] == 1]

# %%
feature_names = vect.get_feature_names()
def get_doc_best_attributes(docnum):
    """Function to get the top attributes from each post"""
    doc = docnum
    #print(doc)
    feature_index = X_vectorized[doc,:].nonzero()[1]
    tfidf_scores = zip(feature_index, [X_vectorized[doc, x] for x in feature_index])
    di = {}
    for w, s in [(feature_names[i],s) for (i, s) in tfidf_scores]:
        di[w] = s
    if(len(di) >= 3):
        sorted_by_value = sorted(di.items(), key=lambda kv: kv[1], reverse=True)
        sorted_by_value = sorted_by_value[:3]
        l = [sorted_by_value[:3][0][0],sorted_by_value[:3][1][0], sorted_by_value[:3][2][0]]
    else:
        l = []
    return l

# %%
## testing the functinon
get_doc_best_attributes(1000)
# Out:
# ['3g', 'wifi', 'mmi']

# %%
df_bmw_lex['Top_Attributes'] = df_bmw_lex.index.map(get_doc_best_attributes)
# Out:
# C:\Users\Preetika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_bmw_lex.head()
# Out:
#                date      username  \
# 0     'September 7'     'dino001'
# 8    'September 24'  'benjaminhf'
# 90        'July 17'   'benjaminh'
# 98        'July 19'   'benjaminh'
# 100       'July 19'    'stickguy'
#
#                                                   post  \
# 0    'If they keep it around in next four-five year...
# 8    "roadburner said:\nAgain, the local dealer are...
# 90   "Alex on Autos, on the other hand, thinks the ...
# 98   "benjaminh said:\nAlex on Autos, on the other ...
# 100  "I have enjoyed listening to people takes on t...
#
#                                                 quotes  \
# 0    "The lease rate is the factor that stops me co...
# 8    'If I do manage to upgrade to a TLX it would h...
# 90   "Alex on Autos, on the other hand, thinks the ...
# 98   'Alfa: 11.8 seconds at 122 mph through the qua...
# 100  "show previous quotes\n\n\n\nBen in the BMW wo...
#
#                                          clean_message  \
# 0    if keep around next fourfive years think make ...
# 8    roadburner saidnagain local dealer hopeless be...
# 90   alex autos hand thinks tchrysler aspec awd clo...
# 98   benjaminh saidnalex autos hand thinks tchrysle...
# 100  i enjoyed listening people takes honda v tchry...
#
#                                             post_clean  BMW or Lexus post  \
# 0    [keep, around, next, four, five, years, think,...                  1
# 8    [roadburner, said, nagain, local, dealer, hope...                  1
# 90   [alex, autos, hand, thinks, tlx, spec, awd, cl...                  1
# 98   [benjaminh, said, nalex, autos, hand, thinks, ...                  1
# 100  [enjoyed, listening, people, takes, accord, v,...                  1
#
#               Top_Attributes
# 0         [oh, mileag, what]
# 8    [hyundai, dealer, look]
# 90         [mpg, calcul, 24]
# 98       [tire, mpg, calcul]
# 100       [x2, 330i, dealer]

# %%
all_attri_bmw_lexv = set(df_bmw_lex['Top_Attributes'].sum())

# %%
(all_attri_bmw_lexv)
# Out:
# {'mercedesbenz',
#  'confus',
#  'till',
#  'net',
#  'readi',
#  'nonnegoti',
#  'everi',
#  'broken',
#  'mirror',
#  'scotch',
#  'zdx',
#  'leatherett',
#  'comput',
#  'unbias',
#  't',
#  'bar',
#  'bundl',
#  'surmis',
#  'couch',
#  'think',
#  'seller',
#  'three',
#  'arguabl',
#  'fair',
#  'ft',
#  'perceiv',
#  'ingolstadt',
#  'press',
#  'othersnni',
#  'de',
#  'implic',
#  'chassi',
#  'mess',
#  'wasnt',
#  '375',
#  'grad',
#  'bmw',
#  'east',
#  'connissant',
#  'panododg',
#  'bill',
#  'accustom',
#  'testdriv',
#  'segmentnni',
#  'someon',
#  'candl',
#  'brand',
#  'effici',
#  'personnel',
#  'simplic',
#  'n54',
#  'hid',
#  'lean',
#  'open',
#  'across',
#  'work',
#  'gadgetri',
#  'robot',
#  'surg',
#  'comprehens',
#  'rock',
#  'opportun',
#  'motion',
#  'wise',
#  'feet',
#  'complaint',
#  'hong',
#  'me',
#  'consid',
#  'upgrad',
#  'kw',
#  'saidnwel',
#  'youth',
#  'moreso',
#  'interview',
#  'fiber',
#  'doe',
#  '190',
#  'lawyer',
#  'prior',
#  'acrua',
#  'downsiz',
#  'virginia',
#  'penalti',
#  'enthusiast',
#  'clutch',
#  'x5d',
#  'plant',
#  'mind',
#  'thrill',
#  'rocket',
#  'region',
#  'decad',
#  'shall',
#  'reward',
#  'trulli',
#  'atsv',
#  'voic',
#  'tester',
#  'requir',
#  'internet',
#  'safe',
#  'german',
#  'carbon',
#  'whi',
#  'sporti',
#  'exhaust',
#  'free',
#  'stitch',
#  'data',
#  'meant',
#  'need',
#  'sam',
#  'weekend',
#  'page',
#  'dark',
#  'sold',
#  'bravo',
#  'blend',
#  'dvda',
#  '7500',
#  'await',
#  'equival',
#  'ellpsnna',
#  'neon',
#  'upfront',
#  '13',
#  'student',
#  'bay',
#  'forward',
#  'ie',
#  'group',
#  'heritag',
#  'what',
#  'school',
#  'pdk',
#  'afraid',
#  'spam',
#  'market',
#  'distress',
#  'distinct',
#  'hi',
#  'guy',
#  'upright',
#  'writer',
#  'cyl',
#  'cop',
#  'pathet',
#  'month',
#  'georg',
#  'agre',
#  'strike',
#  'manymani',
#  'revers',
#  'cushion',
#  'better',
#  'select',
#  'ludicr',
#  'complex',
#  'vacat',
#  'suit',
#  'say',
#  'wherea',
#  'e550',
#  'van',
#  'subscrib',
#  '535d',
#  'build',
#  'prob',
#  'fed',
#  'plagu',
#  'discount',
#  'iirc',
#  's2000',
#  'lazi',
#  'taglin',
#  'low',
#  'youd',
#  'probabl',
#  'tl',
#  'set',
#  'overr',
#  'less',
#  'area',
#  'subscript',
#  'yacht',
#  'butt',
#  '450k',
#  'notori',
#  'recycl',
#  'els',
#  'dynam',
#  'dealt',
#  'elabor',
#  'headlight',
#  'facebook',
#  'blackblack',
#  '6',
#  'nissan',
#  'network',
#  'mazdaudi',
#  'day',
#  'panach',
#  '48000',
#  'saidnnni',
#  'm',
#  '62',
#  'never',
#  'suburb',
#  'mbusa',
#  'walk',
#  'except',
#  'good',
#  'obsolet',
#  'firm',
#  'cb',
#  'pink',
#  '1800',
#  'ought',
#  'automot',
#  'b6',
#  'asid',
#  'cca',
#  'midrang',
#  'fighter',
#  '36k',
#  'lost',
#  'logo',
#  'brain',
#  'rag',
#  'noisi',
#  'age',
#  'bumper',
#  'vast',
#  'commonli',
#  'toonnmi',
#  'stroke',
#  'right',
#  'audiaudi',
#  'bc',
#  '00003',
#  'oh',
#  '3s',
#  'equat',
#  '280',
#  'wrench',
#  'suspens',
#  'stress',
#  'planet',
#  'edmund',
#  'thingnnthey',
#  'trace',
#  'premis',
#  'carnniv',
#  '24k',
#  'vano',
#  '121',
#  'search',
#  'scandal',
#  'costli',
#  'pnni',
#  'standstil',
#  'anim',
#  'corpor',
#  'sidelin',
#  'advisor',
#  '2004',
#  'fiddl',
#  'two',
#  'pretens',
#  '550i',
#  '4',
#  'maintain',
#  '1995',
#  'credit',
#  'trap',
#  'pass',
#  'post',
#  'now',
#  'catena',
#  'ugli',
#  'snow',
#  '200000',
#  'great',
#  'swallow',
#  'pound',
#  'repres',
#  'sale',
#  'behind',
#  'sluggish',
#  'rules45k',
#  'rsa',
#  'gearhead',
#  'ladder',
#  'yield',
#  'simpli',
#  's4',
#  'renam',
#  'smaller',
#  'buy',
#  'bed',
#  'ergonom',
#  '53',
#  'jd',
#  'tan',
#  'belov',
#  'sween',
#  'way',
#  'neck',
#  'mundan',
#  '240z',
#  'hammer',
#  'lust',
#  'cater',
#  'wrap',
#  'eg',
#  '1994',
#  'last',
#  'na',
#  'safelit',
#  'conclud',
#  'i146m',
#  'wrapup',
#  'preced',
#  'mph',
#  'fresh',
#  'stat',
#  'mad',
#  'gon',
#  'band',
#  'elev',
#  '330i',
#  'resid',
#  'decid',
#  '28k',
#  'taho',
#  'conced',
#  'spoiler',
#  'for',
#  '56',
#  '6s',
#  'unlead',
#  'size',
#  'four',
#  'vibrat',
#  'lincoln',
#  'whine',
#  'prelud',
#  'bought',
#  'undoubtedli',
#  'natur',
#  'path',
#  'incent',
#  'lexu',
#  'screw',
#  'rang',
#  'onlin',
#  'cla',
#  'synthet',
#  'screen',
#  'prefer',
#  'sedan',
#  'v6',
#  '75k',
#  'not',
#  'categori',
#  'wouldv',
#  'head',
#  'merrit',
#  'sometim',
#  'list',
#  'lesser',
#  'other',
#  'garag',
#  'look',
#  'decent',
#  '230',
#  'rl',
#  'zealot',
#  'mennth',
#  'ridicul',
#  'town',
#  'pump',
#  'schedul',
#  'mere',
#  '99',
#  'retail',
#  'standard',
#  'isol',
#  'intend',
#  'drive',
#  'gs350',
#  '535',
#  'doodad',
#  'tone',
#  'event',
#  'ed',
#  'offens',
#  'charg',
#  'done',
#  'louder',
#  'looker',
#  'bmwna',
#  'energi',
#  'bring',
#  '61k',
#  '3200',
#  'tire',
#  'color',
#  'face',
#  'odd',
#  'room',
#  '55k',
#  'layout',
#  'built',
#  '14',
#  'clearli',
#  'space',
#  'form',
#  '48',
#  'dime',
#  '1985',
#  'influenc',
#  'tighter',
#  '18t',
#  'fiat',
#  '66',
#  'btw',
#  '650i',
#  'ellp',
#  '86',
#  'awd',
#  'plastic',
#  'insert',
#  'transmiss',
#  'also',
#  'elimin',
#  'racer',
#  'languag',
#  'pontiac5',
#  'wisdom',
#  'crossshop',
#  'rule',
#  'driver',
#  'state',
#  'afternoon',
#  'unlik',
#  'rotor',
#  'interv',
#  'purist',
#  '4dr',
#  'struck',
#  'skin',
#  '800',
#  'useless',
#  'sixti',
#  'stiff',
#  'gear',
#  'sp',
#  'accomplish',
#  'muscl',
#  'perman',
#  'impress',
#  'attract',
#  'engag',
#  'did',
#  'top',
#  'trigger',
#  'recent',
#  'lock',
#  'packag',
#  'clad',
#  'nav',
#  'm4',
#  'citi',
#  'entitl',
#  'ytd',
#  'absolut',
#  'tran',
#  '5000',
#  'fdodge',
#  'journalist',
#  'dhp',
#  'up',
#  'bangl',
#  'experi',
#  'daysxe2x80x99',
#  'currenc',
#  'stinger',
#  'dna',
#  'hand',
#  'minivan',
#  'develop',
#  'beauti',
#  '810th',
#  'trust',
#  'comparo',
#  'record',
#  'constant',
#  'may',
#  'cold',
#  'porsh',
#  'exchang',
#  'choos',
#  'rid',
#  'in',
#  'dealnni',
#  'marketplac',
#  '91',
#  'men',
#  'dieselpow',
#  'dog',
#  'flyer',
#  'grand',
#  'dieselg',
#  '320i',
#  'earliest',
#  'leas',
#  'miata',
#  'puck',
#  'sweat',
#  'repeatedli',
#  'feel',
#  'websit',
#  'newport',
#  'zph',
#  'circa',
#  'comp',
#  'accept',
#  'fiasco',
#  'nowaday',
#  'detail',
#  'hide',
#  'aspir',
#  'goodnni',
#  'stabil',
#  'fine',
#  'battl',
#  'beer',
#  'depend',
#  'enemi',
#  'sampl',
#  'weber',
#  'june',
#  'rs3',
#  'class',
#  'max',
#  'fluid',
#  'drawback',
#  'bm',
#  'trooper',
#  'elsenni',
#  'went',
#  'wagon',
#  'saudi',
#  'easili',
#  'formerli',
#  'gen',
#  'sticker',
#  'nnand',
#  'mark',
#  'potenti',
#  'insur',
#  'duti',
#  '300hp',
#  'inbetween',
#  'bread',
#  'mushi',
#  'legend',
#  '911',
#  'technolog',
#  'blast',
#  'insan',
#  'child',
#  'upcom',
#  'bibl',
#  '36',
#  'm235i',
#  'connect',
#  'cdodgep',
#  'thier',
#  'kd',
#  '2500',
#  'attempt',
#  '30000',
#  'contest',
#  'upper',
#  'dealership',
#  'local',
#  'damag',
#  'sublim',
#  'aspect',
#  'father',
#  'progdodg',
#  'option',
#  'revis',
#  'c7',
#  'buyer',
#  'race',
#  'tune',
#  'sill',
#  '135i',
#  'cc',
#  'foreman',
#  'craze',
#  'do',
#  'horribl',
#  'saidn',
#  'balanc',
#  'elpp',
#  'pull',
#  '666',
#  'whoever',
#  'ta',
#  'took',
#  'wife',
#  'thirti',
#  'chocol',
#  'philosophi',
#  'fail',
#  'titl',
#  'reg',
#  '63k',
#  'mention',
#  'combo',
#  'fantast',
#  'peac',
#  'lighter',
#  'thread',
#  'emot',
#  'defend',
#  'diego',
#  'africa',
#  'gtr',
#  'roadster',
#  'kill',
#  'war',
#  'delta',
#  'contributor',
#  'run',
#  'ani',
#  '331',
#  'embarrass',
#  'ya',
#  'phone',
#  'stab',
#  'bad',
#  'all',
#  'plenti',
#  'nah',
#  'shorten',
#  'be',
#  'vett',
#  'goodlook',
#  'spend',
#  'fuel',
#  'grey',
#  'niec',
#  'reput',
#  'excel',
#  'awdnni',
#  'scare',
#  'dump',
#  'intak',
#  '5050',
#  'breaker',
#  'thursday',
#  'proud',
#  'coil',
#  'absurd',
#  'attitud',
#  'stamford',
#  '060',
#  'bmw7x',
#  'poser',
#  'becaus',
#  'bizarr',
#  'stack',
#  'isnt',
#  'dice',
#  'belt',
#  'name',
#  'consum',
#  'economi',
#  'level',
#  'deer',
#  'incom',
#  'owe',
#  'yup',
#  'half',
#  'came',
#  '2wd',
#  'rpm',
#  'techniqu',
#  'bot',
#  'caught',
#  'dash',
#  'section',
#  '23',
#  'ladi',
#  'nnim',
#  'just',
#  'deliveri',
#  'entranc',
#  'delet',
#  '7seri',
#  'manuel',
#  'word',
#  'intrigu',
#  'scoop',
#  'mash',
#  'es350',
#  'egg',
#  '540i',
#  'cayenn',
#  'util',
#  'mf',
#  'ride',
#  'perfect',
#  'slalom',
#  '460',
#  'tank',
#  'but',
#  'perfectli',
#  'bmwcca',
#  'hover',
#  'order',
#  'wheel',
#  'electr',
#  'nonexist',
#  '46k',
#  'side',
#  'spartanburg',
#  'cash',
#  'appar',
#  'card',
#  'detroit',
#  'breed',
#  'tissu',
#  'enhanc',
#  'hey',
#  'keep',
#  'they',
#  'store',
#  'carri',
#  'residu',
#  'chevrolet',
#  'xle',
#  'subaru',
#  'portfolio',
#  'nada',
#  'system',
#  'tow',
#  'fee',
#  'gc',
#  'front',
#  'navi',
#  'lax',
#  '45k',
#  'disk',
#  'youngest',
#  'epa',
#  'bunch',
#  'bgdc',
#  'imag',
#  'fact',
#  'smg',
#  'felt',
#  'cover',
#  'rockyle',
#  'these',
#  'is300',
#  'miami',
#  'tarnish',
#  'steal',
#  'rais',
#  'sportier',
#  'cheap',
#  'given',
#  'rebuilt',
#  '500',
#  'kick',
#  'dt',
#  'review',
#  'research',
#  'tip',
#  '89',
#  'holder',
#  'throw',
#  'saidnon',
#  'role',
#  'zip',
#  'disagre',
#  'nand',
#  'constitut',
#  'carnnthat',
#  'activ',
#  'catch',
#  'leather',
#  '910th',
#  'show',
#  'of',
#  'kong',
#  'convent',
#  'mainli',
#  'nyccarguy',
#  'glove',
#  'g90',
#  'merc',
#  'late',
#  'leap',
#  'along',
#  'crap',
#  '1989',
#  'queen',
#  'dealer',
#  'recommend',
#  'dishwash',
#  'acceler',
#  'breath',
#  'calendar',
#  'lsc',
#  '430',
#  'talk',
#  'her',
#  'oversight',
#  'idea',
#  'over',
#  'wheeltir',
#  'treat',
#  'vari',
#  'lineup',
#  'door',
#  'fight',
#  'compar',
#  'ignor',
#  'togeth',
#  'smooth',
#  'cubic',
#  'abus',
#  'closer',
#  'nobodi',
#  'effort',
#  'coup',
#  'debt',
#  '1seri',
#  'tremend',
#  '38k',
#  'pleasantli',
#  'dimens',
#  'approx',
#  'trend',
#  'purchas',
#  'note',
#  'buddi',
#  'diesel',
#  'ive',
#  'hurt',
#  'differ',
#  'found',
#  'thesi',
#  'famili',
#  'cabin',
#  '24',
#  'problem',
#  'bs',
#  'flightnurs',
#  'station',
#  'extra',
#  'honda',
#  'perhap',
#  '530i',
#  'downshift',
#  'super',
#  'suppl',
#  'thi',
#  'locat',
#  'stand',
#  'desir',
#  'rick',
#  'chang',
#  'mazda',
#  'red',
#  'younger',
#  'inaccur',
#  'monitor',
#  'protect',
#  'night',
#  'got',
#  'base',
#  '328',
#  'demograph',
#  'unlucki',
#  'resurfac',
#  'gf',
#  'bottl',
#  'valu',
#  'column',
#  'mainstream',
#  'window',
#  'softwar',
#  'complet',
#  'solid',
#  'scroll',
#  'giant',
#  'risk',
#  'stock',
#  'quick',
#  'parallel',
#  'financ',
#  'taut',
#  'step',
#  'nasti',
#  '325i',
#  'blindli',
#  'crown',
#  'stripe',
#  'speech',
#  'reach',
#  'reserv',
#  '41k',
#  'imagin',
#  '2009',
#  'europ',
#  'playbook',
#  'european',
#  'vs',
#  's3',
#  'soul',
#  'defici',
#  'valuabl',
#  'itll',
#  'fold',
#  '528',
#  'settl',
#  'bulk',
#  'volkswagen',
#  'hate',
#  'weigh',
#  'ball',
#  'flagship',
#  'old',
#  'morenni',
#  'hung',
#  'nonenthusiast',
#  'she',
#  'hondaom',
#  'camera',
#  '5k',
#  'industri',
#  'experiencenni',
#  'liter',
#  'finish',
#  'ipad',
#  'cal',
#  'reinforc',
#  'rememb',
#  'via',
#  'oil',
#  'pm',
#  'nich',
#  'would',
#  'certainli',
#  '000',
#  'pale',
#  'import',
#  'mixtur',
#  'past',
#  'input',
#  'stomp',
#  '320d',
#  '60k',
#  'vehicl',
#  '435i',
#  'substanti',
#  'bmw7',
#  '250',
#  'cadillac',
#  'mediocr',
#  'knew',
#  '399',
#  '15',
#  'son',
#  'port',
#  'xxx',
#  'nsx',
#  '07',
#  'predmundscom',
#  '34',
#  'quiet',
#  'fairli',
#  'rumour',
#  'lag',
#  'behavior',
#  'lp',
#  'drivabl',
#  'disapoint',
#  '5',
#  'chase',
#  'shift',
#  ...}

# %% [markdown]
# ### All the different product attributes found with BMW and Lexus
